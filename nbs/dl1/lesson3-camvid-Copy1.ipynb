# %% [markdown]
# ## Image segmentation with CamVid

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# [PosixPath('/home/crcrpar/.fastai/data/camvid/labels'),
#  PosixPath('/home/crcrpar/.fastai/data/camvid/images'),
#  PosixPath('/home/crcrpar/.fastai/data/camvid/valid.txt'),
#  PosixPath('/home/crcrpar/.fastai/data/camvid/codes.txt')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/home/crcrpar/.fastai/data/camvid/images/0001TP_007020.png'),
#  PosixPath('/home/crcrpar/.fastai/data/camvid/images/Seq05VD_f02460.png'),
#  PosixPath('/home/crcrpar/.fastai/data/camvid/images/0016E5_06870.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/home/crcrpar/.fastai/data/camvid/labels/0016E5_04410_P.png'),
#  PosixPath('/home/crcrpar/.fastai/data/camvid/labels/Seq05VD_f02280_P.png'),
#  PosixPath('/home/crcrpar/.fastai/data/camvid/labels/Seq05VD_f01290_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[26, 26, 26,  ...,  4,  4,  4],
#           [26, 26, 26,  ...,  4,  4,  4],
#           [26, 26, 26,  ...,  4,  4,  4],
#           ...,
#           [15, 15, 15,  ..., 30, 30, 30],
#           [15, 15, 15,  ..., 30, 30, 30],
#           [15, 15, 15,  ..., 30, 30, 30]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2
bs=6

# %%
size, bs
# Out:
# (array([360, 480]), 6)

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# Total time: 08:09 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.144908</th>
#     <th>0.792553</th>
#     <th>0.797799</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.777870</th>
#     <th>0.600929</th>
#     <th>0.839747</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.691197</th>
#     <th>0.967383</th>
#     <th>0.766556</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.676321</th>
#     <th>0.538879</th>
#     <th>0.850597</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.622622</th>
#     <th>0.601230</th>
#     <th>0.850454</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.578596</th>
#     <th>0.519060</th>
#     <th>0.865150</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.573080</th>
#     <th>0.527878</th>
#     <th>0.854829</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.579767</th>
#     <th>0.495504</th>
#     <th>0.864663</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.513570</th>
#     <th>0.389758</th>
#     <th>0.895999</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.437614</th>
#     <th>0.341607</th>
#     <th>0.894808</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# Total time: 10:09 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.379063</th>
#     <th>0.322569</th>
#     <th>0.898866</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.373727</th>
#     <th>0.320237</th>
#     <th>0.899361</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.364943</th>
#     <th>0.320260</th>
#     <th>0.897291</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.357351</th>
#     <th>0.305855</th>
#     <th>0.901141</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.346186</th>
#     <th>0.293302</th>
#     <th>0.914892</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.341205</th>
#     <th>0.292466</th>
#     <th>0.914214</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.333298</th>
#     <th>0.274526</th>
#     <th>0.924327</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.333662</th>
#     <th>0.301114</th>
#     <th>0.907587</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.319096</th>
#     <th>0.302124</th>
#     <th>0.913113</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.317216</th>
#     <th>0.271695</th>
#     <th>0.921939</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.288978</th>
#     <th>0.264134</th>
#     <th>0.924455</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.261949</th>
#     <th>0.267759</th>
#     <th>0.925124</th>
#   </tr>
# </table>

# %%
learn.save('stage-2');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn = None
gc.collect()
torch.cuda.empty_cache()

# %%
size = src_size
bs=1
size, bs
# Out:
# (array([720, 960]), 1)

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# Total time: 20:31 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.366140</th>
#     <th>0.339497</th>
#     <th>0.908682</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.333278</th>
#     <th>0.304011</th>
#     <th>0.916702</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.326025</th>
#     <th>0.305404</th>
#     <th>0.919941</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.336885</th>
#     <th>0.321342</th>
#     <th>0.910933</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.326935</th>
#     <th>0.305589</th>
#     <th>0.919401</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.347779</th>
#     <th>0.333608</th>
#     <th>0.908895</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.328334</th>
#     <th>0.352358</th>
#     <th>0.905482</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.327277</th>
#     <th>0.387525</th>
#     <th>0.912187</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.291777</th>
#     <th>0.293065</th>
#     <th>0.918046</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.228348</th>
#     <th>0.257859</th>
#     <th>0.929750</th>
#   </tr>
# </table>

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)
# Out:
# Total time: 21:05 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.225999</th>
#     <th>0.254650</th>
#     <th>0.930782</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.216341</th>
#     <th>0.256007</th>
#     <th>0.930751</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.209800</th>
#     <th>0.255649</th>
#     <th>0.930709</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.203509</th>
#     <th>0.252857</th>
#     <th>0.931682</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.202308</th>
#     <th>0.258498</th>
#     <th>0.931308</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.200796</th>
#     <th>0.257311</th>
#     <th>0.931915</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.204560</th>
#     <th>0.251486</th>
#     <th>0.933218</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.192893</th>
#     <th>0.254977</th>
#     <th>0.932786</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.189505</th>
#     <th>0.258091</th>
#     <th>0.932555</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.190156</th>
#     <th>0.256064</th>
#     <th>0.933315</th>
#   </tr>
# </table>

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))

# %% [markdown]
# ## fin
